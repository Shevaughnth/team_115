# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('merged_obesity.csv')
df.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-b2142b813851> in <module>
# ----> 1 df = pd.read_csv('merged_obesity.csv')
#       2 df.info()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'merged_obesity.csv' does not exist: b'merged_obesity.csv'

# %%
df_working = df.dropna(axis=0,subset=['obesity_rate'])
df_working = df_working.drop(['fips', 'state', 'county', 'region'], axis=1)
df_working.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3109 entries, 0 to 3149
# Data columns (total 48 columns):
# Unnamed: 0                           3109 non-null int64
# percent_pop_low_access_15            3090 non-null float64
# percent_low_income_low_access_15     3090 non-null float64
# percent_no_car_low_access_15         3107 non-null float64
# percent_snap_low_access_15           3090 non-null float64
# percent_child_low_access_15          3090 non-null float64
# percent_senior_low_access_15         3090 non-null float64
# percent_white_low_access_15          3090 non-null float64
# percent_black_low_access_15          3090 non-null float64
# percent_hispanic_low_access_15       3090 non-null float64
# percent_asian_low_access_15          3090 non-null float64
# percent_nhna_low_access_15           3090 non-null float64
# nhpi_low_access_15                   3090 non-null float64
# percent_nhpi_low_access_15           3090 non-null float64
# percent_multiracial_low_access_15    3090 non-null float64
# grocery_per1000                      3109 non-null float64
# super_per1000                        3109 non-null float64
# convenience_per1000                  3109 non-null float64
# specialty_per1000                    3109 non-null float64
# snap_available_per1000               3088 non-null float64
# wic_available_per1000                2953 non-null float64
# obesity_rate                         3109 non-null float64
# farmers_markets_per1000              3108 non-null float64
# pct_fm_accepting_snap                3109 non-null float64
# pct_fm_accept_wic                    3109 non-null float64
# pct_fm_credit                        3109 non-null float64
# fm_sell_frveg                        3109 non-null float64
# pct_fm_sell_frveg                    3109 non-null float64
# fi_rate                              3108 non-null float64
# child_fi_rate                        3108 non-null float64
# cost_per_meal                        3108 non-null float64
# est_annual_food_budget_shortfall     3108 non-null float64
# snap_bens_per1000                    3057 non-null float64
# school_lunch_prog_17                 3109 non-null float64
# school_bfast_prog_17                 3109 non-null float64
# smr_food_prog_17                     3109 non-null float64
# wic_parts_pop_17                     3109 non-null float64
# fast_food_per1000                    3109 non-null float64
# full_service_per1000                 3109 non-null float64
# pop_estimate                         3108 non-null float64
# percent_white                        3108 non-null float64
# percent_black                        3108 non-null float64
# percent_native_american              3108 non-null float64
# percent_asian                        3108 non-null float64
# percent_nhpi                         3108 non-null float64
# percent_multi                        3108 non-null float64
# percent_nonwhite_hispanic            3108 non-null float64
# median_household_income              3108 non-null float64
# dtypes: float64(47), int64(1)
# memory usage: 1.2 MB

# %%
corr = df_working.corr()

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
