# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
obesity = pd.read_csv(r"C:\Users\anneg\Documents\Correlation1\Data\obesity.csv")
obesity.head(10)
obesity
# Out:
#          State                                 County   FIPS  2005  2006  \
# 0      Alabama                                Autauga   1001  23.6  24.5
# 1      Alabama                                Baldwin   1003  17.5  18.4
# 2      Alabama                                Barbour   1005  30.9  31.8
# 3      Alabama                                   Bibb   1007  28.0  28.9
# 4      Alabama                                 Blount   1009  28.4  29.3
# ...        ...                                    ...    ...   ...   ...
# 3104  Virginia                      Falls Church City  51610  24.7  25.6
# 3105  Virginia  Halifax County with South Boston City  51083  35.1  36.0
# 3106  Virginia                     Manassas Park City  51685  25.3  26.2
# 3107  Virginia                      Newport News City  51700  27.3  28.2
# 3108  Virginia                    Virginia Beach City  51810  24.7  25.6
#
#       2007  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  2018  \
# ...

# %%
#checking duplicates
obesity_clean=obesity.drop_duplicates(['FIPS'])
obesity_clean
#there are 7 duplicates
# Out:
#          State                                 County   FIPS  2005  2006  \
# 0      Alabama                                Autauga   1001  23.6  24.5
# 1      Alabama                                Baldwin   1003  17.5  18.4
# 2      Alabama                                Barbour   1005  30.9  31.8
# 3      Alabama                                   Bibb   1007  28.0  28.9
# 4      Alabama                                 Blount   1009  28.4  29.3
# ...        ...                                    ...    ...   ...   ...
# 3104  Virginia                      Falls Church City  51610  24.7  25.6
# 3105  Virginia  Halifax County with South Boston City  51083  35.1  36.0
# 3106  Virginia                     Manassas Park City  51685  25.3  26.2
# 3107  Virginia                      Newport News City  51700  27.3  28.2
# 3108  Virginia                    Virginia Beach City  51810  24.7  25.6
#
#       2007  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  2018  \
# ...

# %%
#create regions
B = obesity_clean.groupby(["State"])[["2019"]].mean()
B
# Out:
#                            2019
# State
# Alabama               36.910448
# Arizona               28.246667
# Arkansas              36.117333
# California            24.184483
# Colorado              21.221875
# Connecticut           25.700000
# Delaware              31.466667
# District of Columbia  22.800000
# Florida               29.852239
# Georgia               31.931447
# Idaho                 29.193182
# Illinois              29.320588
# Indiana               32.705435
# Iowa                  33.141414
# Kansas                33.920952
# Kentucky              35.231667
# Louisiana             35.910938
# Maine                 29.693750
# Maryland              31.565217
# Massachusetts         23.792857
# Michigan              32.249398
# Minnesota             30.048276
# Mississippi           36.737805
# Missouri              33.043860
# Montana               27.178571
# Nebraska              32.638710
# Nevada                27.947059
# New Hampshire         28.260000
# ...

# %%
state = pd.read_csv(r"C:\Users\anneg\Documents\Correlation1\Data\state.csv")
state.head(10)
# Out:
#    FIPS State_1
# 0  1001      AL
# 1  1003      AL
# 2  1005      AL
# 3  1007      AL
# 4  1009      AL
# 5  1011      AL
# 6  1013      AL
# 7  1015      AL
# 8  1017      AL
# 9  1019      AL

# %%
obe_clean=pd.merge(obesity_clean, state, on='FIPS')
obe_clean.head(10)
# Out:
#      State    County  FIPS  2005  2006  2007  2008  2009  2010  2011  2012  \
# 0  Alabama   Autauga  1001  23.6  24.5  25.3  26.8  27.0  28.5  30.0  31.5
# 1  Alabama   Baldwin  1003  17.5  18.4  19.2  20.9  21.1  22.8  24.5  26.2
# 2  Alabama   Barbour  1005  30.9  31.8  32.6  33.8  34.0  35.2  36.4  37.6
# 3  Alabama      Bibb  1007  28.0  28.9  29.7  30.3  30.5  31.1  31.7  32.3
# 4  Alabama    Blount  1009  28.4  29.3  30.1  30.5  30.7  31.1  31.5  31.9
# 5  Alabama   Bullock  1011  33.9  34.8  35.6  36.1  36.3  36.8  37.3  37.8
# 6  Alabama    Butler  1013  29.7  30.6  31.4  32.7  32.9  34.2  35.5  36.8
# 7  Alabama   Calhoun  1015  30.4  31.3  32.1  32.4  32.6  32.9  33.2  33.5
# 8  Alabama  Chambers  1017  34.4  35.3  36.1  35.9  36.1  35.9  35.7  35.5
# 9  Alabama  Cherokee  1019  26.4  27.3  28.1  28.9  29.1  29.9  30.7  31.5
#
#    2013  2014  2015  2016  2017  2018  2019 State_1
# 0  34.1  34.1  30.5  31.3  30.9  34.1  36.4      AL
# ...

# %%
states = {
        'AK': 'O',
        'AL': 'S',
        'AR': 'S',
        'AS': 'O',
        'AZ': 'W',
        'CA': 'W',
        'CO': 'W',
        'CT': 'N',
        'DC': 'N',
        'DE': 'N',
        'FL': 'S',
        'GA': 'S',
        'GU': 'O',
        'HI': 'O',
        'IA': 'M',
        'ID': 'W',
        'IL': 'M',
        'IN': 'M',
        'KS': 'M',
        'KY': 'S',
        'LA': 'S',
        'MA': 'N',
        'MD': 'N',
        'ME': 'N',
        'MI': 'W',
        'MN': 'M',
        'MO': 'M',
        'MP': 'O',
        'MS': 'S',
        'MT': 'W',
        'NA': 'O',
        'NC': 'S',
        'ND': 'M',
        'NE': 'W',
        'NH': 'N',
        'NJ': 'N',
        'NM': 'W',
        'NV': 'W',
        'NY': 'N',
        'OH': 'M',
        'OK': 'S',
        'OR': 'W',
        'PA': 'N',
        'PR': 'O',
        'RI': 'N',
        'SC': 'S',
        'SD': 'M',
        'TN': 'S',
        'TX': 'S',
        'UT': 'W',
        'VA': 'S',
        'VI': 'O',
        'VT': 'N',
        'WA': 'W',
        'WI': 'M',
        'WV': 'S',
        'WY': 'W'
}
    
obe_clean['Region'] = obe_clean['State_1'].map(states)
                          
obe_clean
# Out:
#          State                                 County   FIPS  2005  2006  \
# 0      Alabama                                Autauga   1001  23.6  24.5
# 1      Alabama                                Baldwin   1003  17.5  18.4
# 2      Alabama                                Barbour   1005  30.9  31.8
# 3      Alabama                                   Bibb   1007  28.0  28.9
# 4      Alabama                                 Blount   1009  28.4  29.3
# ...        ...                                    ...    ...   ...   ...
# 3097  Virginia                      Falls Church City  51610  24.7  25.6
# 3098  Virginia  Halifax County with South Boston City  51083  35.1  36.0
# 3099  Virginia                     Manassas Park City  51685  25.3  26.2
# 3100  Virginia                      Newport News City  51700  27.3  28.2
# 3101  Virginia                    Virginia Beach City  51810  24.7  25.6
#
#       2007  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  2018  \
# ...

# %%
groups = obe_clean.groupby(["Region"])
groups["2019"].mean()
# Out:
# Region
# M    32.203759
# N    28.866803
# S    32.916259
# W    28.153729
# Name: 2019, dtype: float64

# %%
boxplot = sns.boxplot(x="Region", y="2019", showfliers= True, data= obe_clean)
